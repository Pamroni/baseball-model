# %%
import statsapi

# statsapi.schedule(start_date='04/01/2024', end_date='09/30/2024') # get all games for a team - game_id 746994

statsapi.boxscore_data(gamePk='746994') # get boxscore for a game

# statsapi.roster(teamId=117, season=2024, date="09/30/2024") # get roster for a team

# %%
statsapi.linescore(gamePk='746994') # get linescore for a game

# %%
statsapi.get('game',{'gamePk': 661848})
# Out:
# {'copyright': 'Copyright 2024 MLB Advanced Media, L.P.  Use of any content on this page acknowledges agreement to the terms posted here http://gdx.mlb.com/components/copyright.txt',
#  'gamePk': 661848,
#  'link': '/api/v1.1/game/661848/feed/live',
#  'metaData': {'wait': 10,
#   'timeStamp': '20220911_231340',
#   'gameEvents': ['field_out', 'game_finished'],
#   'logicalEvents': ['midInning',
#    'countChange',
#    'count12',
#    'newRightHandedHit',
#    'basesEmpty',
#    'gameStateChangeToGameOver']},
#  'gameData': {'game': {'pk': 661848,
#    'type': 'R',
#    'doubleHeader': 'N',
#    'id': '2022/09/11/lanmlb-sdnmlb-1',
#    'gamedayType': 'P',
#    'tiebreaker': 'N',
#    'gameNumber': 1,
#    'calendarEventID': '14-661848-2022-09-11',
#    'season': '2022',
#    'seasonDisplay': '2022'},
#   'datetime': {'dateTime': '2022-09-11T20:10:00Z',
#    'originalDate': '2022-09-11',
#    'officialDate': '2022-09-11',
#    'dayNight': 'day',
#    'time': '1:10',
#    'ampm': 'PM'},
#   'status': {'abstractGameState': 'Final',
#    'codedGameState': 'F',
#    'detailedState': 'Final',
#    'statusCode': 'F',
#    'startTimeTBD': False,
#    'abstractGameCode': 'F'},
#   'teams': {'away': {'springLeague': {'id': 114,
#      'name': 'Cactus League',
#      'link': '/api/v1/league/114',
#      'abbreviation': 'CL'},
#     'allStarStatus': 'N',
#     'id': 119,
#     'name': 'Los Angeles Dodgers',
#     'link': '/api/v1/teams/119',
#     'season': 2022,
#     'venue': {'id': 22, 'name': 'Dodger Stadium', 'link': '/api/v1/venues/22'},
#     'springVenue': {'id': 3809, 'link': '/api/v1/venues/3809'},
#     'teamCode': 'lan',
#     'fileCode': 'la',
#     'abbreviation': 'LAD',
#     'teamName': 'Dodgers',
#     'locationName': 'Los Angeles',
#     'firstYearOfPlay': '1884',
#     'league': {'id': 104,
#      'name': 'National League',
#      'link': '/api/v1/league/104'},
#     'division': {'id': 203,
#      'name': 'National League West',
#      'link': '/api/v1/divisions/203'},
#     'sport': {'id': 1,
#      'link': '/api/v1/sports/1',
#      'name': 'Major League Baseball'},
#     'shortName': 'LA Dodgers',
#     'record': {'gamesPlayed': 139,
#      'wildCardGamesBack': '-',
#      'leagueGamesBack': '-',
#      'springLeagueGamesBack': '-',
#      'sportGamesBack': '-',
#      'divisionGamesBack': '-',
#      'conferenceGamesBack': '-',
#      'leagueRecord': {'wins': 96, 'losses': 43, 'ties': 0, 'pct': '.691'},
#      'records': {},
#      'divisionLeader': False,
#      'wins': 96,
#      'losses': 43,
#      'winningPercentage': '.691'},
#     'franchiseName': 'Los Angeles',
#     'clubName': 'Dodgers',
#     'active': True},
#    'home': {'springLeague': {'id': 114,
#      'name': 'Cactus League',
#      'link': '/api/v1/league/114',
#      'abbreviation': 'CL'},
#     'allStarStatus': 'N',
#     'id': 135,
#     'name': 'San Diego Padres',
#     'link': '/api/v1/teams/135',
#     'season': 2022,
#     'venue': {'id': 2680, 'name': 'Petco Park', 'link': '/api/v1/venues/2680'},
#     'springVenue': {'id': 2530, 'link': '/api/v1/venues/2530'},
#     'teamCode': 'sdn',
#     'fileCode': 'sd',
#     'abbreviation': 'SD',
#     'teamName': 'Padres',
#     'locationName': 'San Diego',
#     'firstYearOfPlay': '1968',
#     'league': {'id': 104,
#      'name': 'National League',
#      'link': '/api/v1/league/104'},
#     'division': {'id': 203,
#      'name': 'National League West',
#      'link': '/api/v1/divisions/203'},
#     'sport': {'id': 1,
#      'link': '/api/v1/sports/1',
#      'name': 'Major League Baseball'},
#     'shortName': 'San Diego',
#     'record': {'gamesPlayed': 141,
#      'wildCardGamesBack': '-',
#      'leagueGamesBack': '-',
#      'springLeagueGamesBack': '-',
#      'sportGamesBack': '-',
#      'divisionGamesBack': '-',
#      'conferenceGamesBack': '-',
#      'leagueRecord': {'wins': 77, 'losses': 64, 'ties': 0, 'pct': '.546'},
#      'records': {},
#      'divisionLeader': False,
#      'wins': 77,
#      'losses': 64,
#      'winningPercentage': '.546'},
#     'franchiseName': 'San Diego',
#     'clubName': 'Padres',
#     'active': True}},
#   'players': {'ID669257': {'id': 669257,
#     'fullName': 'Will Smith',
#     'link': '/api/v1/people/669257',
#     'firstName': 'William',
#     'lastName': 'Smith',
#     'primaryNumber': '16',
#     'birthDate': '1995-03-28',
#     'currentAge': 29,
#     'birthCity': 'Louisville',
#     'birthStateProvince': 'KY',
#     'birthCountry': 'USA',
#     'height': '5\' 10"',
#     'weight': 195,
#     'active': True,
#     'primaryPosition': {'code': '2',
#      'name': 'Catcher',
#      'type': 'Catcher',
#      'abbreviation': 'C'},
#     'useName': 'Will',
#     'useLastName': 'Smith',
#     'middleName': 'Dills',
#     'boxscoreName': 'Smith, W.D.',
#     'nickName': 'Smitty',
#     'gender': 'M',
#     'isPlayer': True,
#     'isVerified': False,
#     'draftYear': 2016,
#     'mlbDebutDate': '2019-05-28',
#     'batSide': {'code': 'R', 'description': 'Right'},
#     'pitchHand': {'code': 'R', 'description': 'Right'},
#     'nameFirstLast': 'Will Smith',
#     'nameSlug': 'will-smith-669257',
#     'firstLastName': 'Will Smith',
#     'lastFirstName': 'Smith, Will',
#     'lastInitName': 'Smith, W',
#     'initLastName': 'W Smith',
#     'fullFMLName': 'William Dills Smith',
#     'fullLFMName': 'Smith, William Dills',
#     'strikeZoneTop': 3.27,
#     'strikeZoneBottom': 1.48},
#    'ID642451': {'id': 642451,
#     'fullName': 'Luis Liberato',
#     'link': '/api/v1/people/642451',
#     'firstName': 'Luis',
#     'lastName': 'Liberato',
#     'primaryNumber': '76',
#     'birthDate': '1995-12-18',
#     'currentAge': 28,
#     'birthCity': 'La Canela',
#     'birthCountry': 'Dominican Republic',
#     'height': '6\' 1"',
#     'weight': 175,
#     'active': True,
#     'primaryPosition': {'code': 'O',
#      'name': 'Outfield',
#      'type': 'Outfielder',
#      'abbreviation': 'OF'},
#     'useName': 'Luis',
#     'useLastName': 'Liberato',
#     'middleName': 'David',
#     'boxscoreName': 'Liberato',
#     'gender': 'M',
#     'nameMatrilineal': 'Grullon',
#     'isPlayer': True,
#     'isVerified': True,
#     'mlbDebutDate': '2022-09-10',
#     'batSide': {'code': 'L', 'description': 'Left'},
#     'pitchHand': {'code': 'L', 'description': 'Left'},
#     'nameFirstLast': 'Luis Liberato',
#     'nameSlug': 'luis-liberato-642451',
#     'firstLastName': 'Luis Liberato',
#     'lastFirstName': 'Liberato, Luis',
#     'lastInitName': 'Liberato, L',
#     'initLastName': 'L Liberato',
#     'fullFMLName': 'Luis David Liberato',
#     'fullLFMName': 'Liberato, Luis David',
#     'strikeZoneTop': 3.411,
#     'strikeZoneBottom': 1.565},
#    'ID641360': {'id': 641360,
#     'fullName': 'Phil Bickford',
#     'link': '/api/v1/people/641360',
#     'firstName': 'Phillip',
#     'lastName': 'Bickford',
#     'primaryNumber': '53',
#     'birthDate': '1995-07-10',
#     'currentAge': 29,
#     'birthCity': 'Ventura',
#     'birthStateProvince': 'CA',
#     'birthCountry': 'USA',
#     'height': '6\' 4"',
#     'weight': 200,
#     'active': True,
#     'primaryPosition': {'code': '1',
#      'name': 'Pitcher',
#      'type': 'Pitcher',
#      'abbreviation': 'P'},
#     'useName': 'Phil',
#     'useLastName': 'Bickford',
#     'middleName': 'Roger',
#     'boxscoreName': 'Bickford',
#     'gender': 'M',
#     'isPlayer': True,
#     'isVerified': True,
#     'draftYear': 2015,
#     'mlbDebutDate': '2020-09-01',
#     'batSide': {'code': 'R', 'description': 'Right'},
#     'pitchHand': {'code': 'R', 'description': 'Right'},
#     'nameFirstLast': 'Phil Bickford',
#     'nameSlug': 'phil-bickford-641360',
#     'firstLastName': 'Phil Bickford',
#     'lastFirstName': 'Bickford, Phil',
#     'lastInitName': 'Bickford, P',
#     'initLastName': 'P Bickford',
#     'fullFMLName': 'Phillip Roger Bickford',
#     'fullLFMName': 'Bickford, Phillip Roger',
#     'strikeZoneTop': 3.549,
#     'strikeZoneBottom': 1.627},
#    'ID621035': {'id': 621035,
#     'fullName': 'Chris Taylor',
#     'link': '/api/v1/people/621035',
#     'firstName': 'Christopher',
#     'lastName': 'Taylor',
#     'primaryNumber': '3',
#     'birthDate': '1990-08-29',
#     'currentAge': 34,
#     'birthCity': 'Virginia Beach',
#     'birthStateProvince': 'VA',
#     'birthCountry': 'USA',
#     'height': '6\' 1"',
#     'weight': 196,
#     'active': True,
#     'primaryPosition': {'code': '7',
#      'name': 'Outfielder',
#      'type': 'Outfielder',
#      'abbreviation': 'LF'},
#     'useName': 'Chris',
#     'useLastName': 'Taylor',
#     'middleName': 'Armand',
#     'boxscoreName': 'Taylor, Ch',
#     'nickName': 'CT3',
#     'gender': 'M',
#     'isPlayer': True,
#     'isVerified': True,
#     'draftYear': 2012,
#     'mlbDebutDate': '2014-07-24',
#     'batSide': {'code': 'R', 'description': 'Right'},
#     'pitchHand': {'code': 'R', 'description': 'Right'},
#     'nameFirstLast': 'Chris Taylor',
#     'nameSlug': 'chris-taylor-621035',
#     'firstLastName': 'Chris Taylor',
#     'lastFirstName': 'Taylor, Chris',
#     'lastInitName': 'Taylor, C',
#     'initLastName': 'C Taylor',
#     'fullFMLName': 'Christopher Armand Taylor',
#     'fullLFMName': 'Taylor, Christopher Armand',
#     'strikeZoneTop': 3.57,
#     'strikeZoneBottom': 1.67},
#    'ID669134': {'id': 669134,
#     'fullName': 'Luis Campusano',
#     'link': '/api/v1/people/669134',
#     'firstName': 'Luis',
#     'lastName': 'Campusano',
#     'primaryNumber': '12',
#     'birthDate': '1998-09-29',
#     'currentAge': 26,
#     'birthCity': 'Augusta',
#     'birthStateProvince': 'GA',
#     'birthCountry': 'USA',
#     'height': '5\' 11"',
#     'weight': 232,
#     'active': True,
#     'primaryPosition': {'code': '2',
#      'name': 'Catcher',
#      'type': 'Catcher',
#      'abbreviation': 'C'},
#     'useName': 'Luis',
#     'useLastName': 'Campusano',
#     'middleName': 'Genaro',
#     'boxscoreName': 'Campusano',
#     'gender': 'M',
#     'nameMatrilineal': 'Bracero',
#     'isPlayer': True,
#     'isVerified': False,
#     'draftYear': 2017,
#     'pronunciation': 'cam-poo-SAHN-know',
#     'mlbDebutDate': '2020-09-04',
#     'batSide': {'code': 'R', 'description': 'Right'},
#     'pitchHand': {'code': 'R', 'description': 'Right'},
#     'nameFirstLast': 'Luis Campusano',
#     'nameSlug': 'luis-campusano-669134',
#     'firstLastName': 'Luis Campusano',
#     'lastFirstName': 'Campusano, Luis',
#     'lastInitName': 'Campusano, L',
#     'initLastName': 'L Campusano',
#     'fullFMLName': 'Luis Genaro Campusano',
#     'fullLFMName': 'Campusano, Luis Genaro',
#     'strikeZoneTop': 3.44,
#     'strikeZoneBottom': 1.54},
#    'ID663158': {'id': 663158,
#     'fullName': 'Robert Suarez',
#     'link': '/api/v1/people/663158',
#     'firstName': 'Robert',
#     'lastName': 'Suarez',
#     'primaryNumber': '75',
#     'birthDate': '1991-03-01',
#     'currentAge': 33,
#     'birthCity': 'Bolivar',
#     'birthCountry': 'Venezuela',
#     'height': '6\' 2"',
#     'weight': 210,
#     'active': True,
#     'primaryPosition': {'code': '1',
#      'name': 'Pitcher',
#      'type': 'Pitcher',
#      'abbreviation': 'P'},
#     'useName': 'Robert',
#     'useLastName': 'Suarez',
#     'middleName': 'Alexander',
#     'boxscoreName': 'Suarez, Ro',
#     'gender': 'M',
#     'nameMatrilineal': 'Subero',
#     'isPlayer': True,
#     'isVerified': False,
#     'mlbDebutDate': '2022-04-07',
#     'batSide': {'code': 'R', 'description': 'Right'},
#     'pitchHand': {'code': 'R', 'description': 'Right'},
#     'nameFirstLast': 'Robert Suarez',
#     'nameSlug': 'robert-suarez-663158',
#     'firstLastName': 'Robert Suarez',
#     'lastFirstName': 'Suarez, Robert',
#     'lastInitName': 'Suarez, R',
#     'initLastName': 'R Suarez',
#     'fullFMLName': 'Robert Alexander Suarez',
#     'fullLFMName': 'Suarez, Robert Alexander',
#     'strikeZoneTop': 3.467,
#     'strikeZoneBottom': 1.589},
#    'ID666703': {'id': 666703,
#     'fullName': 'Eguy Rosario',
#     'link': '/api/v1/people/666703',
#     'firstName': 'Eguy',
#     'lastName': 'Rosario',
#     'primaryNumber': '5',
#     'birthDate': '1999-08-25',
#     'currentAge': 25,
#     'birthCity': 'Juan Baron',
#     'birthCountry': 'Dominican Republic',
#     'height': '5\' 7"',
#     'weight': 150,
#     'active': True,
#     'primaryPosition': {'code': '5',
#      'name': 'Third Base',
#      'type': 'Infielder',
#      'abbreviation': '3B'},
#     'useName': 'Eguy',
#     'useLastName': 'Rosario',
#     'boxscoreName': 'Rosario, E',
#     'gender': 'M',
#     'nameMatrilineal': 'Valdez',
#     'isPlayer': True,
#     'isVerified': False,
#     'pronunciation': 'EGGY ro-SAHR-ee-oh',
#     'mlbDebutDate': '2022-08-26',
#     'batSide': {'code': 'R', 'description': 'Right'},
#     'pitchHand': {'code': 'R', 'description': 'Right'},
#     'nameFirstLast': 'Eguy Rosario',
#     'nameSlug': 'eguy-rosario-666703',
#     'firstLastName': 'Eguy Rosario',
#     'lastFirstName': 'Rosario, Eguy',
#     'lastInitName': 'Rosario, E',
#     'initLastName': 'E Rosario',
#     'fullFMLName': 'Eguy Rosario',
#     'fullLFMName': 'Rosario, Eguy',
#     'strikeZoneTop': 3.39,
#     'strikeZoneBottom': 1.61},
#    'ID595777': {'id': 595777,
#     'fullName': 'Jurickson Profar',
#     'link': '/api/v1/people/595777',
#     'firstName': 'Jurickson',
#     'lastName': 'Profar',
#     'primaryNumber': '10',
#     'birthDate': '1993-02-20',
#     'currentAge': 31,
#     'birthCity': 'Willemstad',
#     'birthCountry': 'Curacao',
#     'height': '6\' 0"',
#     'weight': 184,
#     'active': True,
#     'primaryPosition': {'code': '7',
#      'name': 'Outfielder',
#      'type': 'Outfielder',
#      'abbreviation': 'LF'},
#     'useName': 'Jurickson',
#     'useLastName': 'Profar',
#     'middleName': 'Barthelomeus',
#     'boxscoreName': 'Profar, J',
#     'nickName': 'El Patron',
#     'gender': 'M',
#     'isPlayer': True,
#     'isVerified': True,
#     'pronunciation': 'JUR-ick-son PRO-far',
#     'mlbDebutDate': '2012-09-02',
#     'batSide': {'code': 'S', 'description': 'Switch'},
#     'pitchHand': {'code': 'R', 'description': 'Right'},
#     'nameFirstLast': 'Jurickson Profar',
#     'nameSlug': 'jurickson-profar-595777',
#     'firstLastName': 'Jurickson Profar',
#     'lastFirstName': 'Profar, Jurickson',
#     'lastInitName': 'Profar, J',
#     'initLastName': 'J Profar',
#     'fullFMLName': 'Jurickson Barthelomeus Profar',
#     'fullLFMName': 'Profar, Jurickson Barthelomeus',
#     'strikeZoneTop': 3.35,
#     'strikeZoneBottom': 1.62},
#    'ID605397': {'id': 605397,
#     'fullName': 'Joe Musgrove',
#     'link': '/api/v1/people/605397',
#     'firstName': 'Joseph',
#     'lastName': 'Musgrove',
#     'primaryNumber': '44',
#     'birthDate': '1992-12-04',
#     'currentAge': 31,
#     'birthCity': 'El Cajon',
#     'birthStateProvince': 'CA',
#     'birthCountry': 'USA',
#     'height': '6\' 5"',
#     'weight': 230,
#     'active': True,
#     'primaryPosition': {'code': '1',
#      'name': 'Pitcher',
#      'type': 'Pitcher',
#      'abbreviation': 'P'},
#     'useName': 'Joe',
#     'useLastName': 'Musgrove',
#     'middleName': 'Anthony',
#     'boxscoreName': 'Musgrove',
#     'nickName': 'Moose',
#     'gender': 'M',
#     'isPlayer': True,
#     'isVerified': True,
#     'draftYear': 2011,
#     'mlbDebutDate': '2016-08-02',
#     'batSide': {'code': 'R', 'description': 'Right'},
#     'pitchHand': {'code': 'R', 'description': 'Right'},
#     'nameFirstLast': 'Joe Musgrove',
#     'nameSlug': 'joe-musgrove-605397',
#     'firstLastName': 'Joe Musgrove',
#     'lastFirstName': 'Musgrove, Joe',
#     'lastInitName': 'Musgrove, J',
#     'initLastName': 'J Musgrove',
#     'fullFMLName': 'Joseph Anthony Musgrove',
#     'fullLFMName': 'Musgrove, Joseph Anthony',
#     'strikeZoneTop': 3.69,
#     'strikeZoneBottom': 1.78},
#    'ID571970': {'id': 571970,
#     'fullName': 'Max Muncy',
#     'link': '/api/v1/people/571970',
#     'firstName': 'Maxwell',
#     'lastName': 'Muncy',
#     'primaryNumber': '13',
#     'birthDate': '1990-08-25',
#     'currentAge': 34,
#     'birthCity': 'Midland',
#     'birthStateProvince': 'TX',
#     'birthCountry': 'USA',
#     'height': '6\' 0"',
#     'weight': 215,
#     'active': True,
#     'primaryPosition': {'code': '5',
#      'name': 'Third Base',
#      'type': 'Infielder',
#      'abbreviation': '3B'},
#     'useName': 'Max',
#     'useLastName': 'Muncy',
#     'middleName': 'Steven',
#     'boxscoreName': 'Muncy',
#     'nickName': 'Funky Muncy',
#     'gender': 'M',
#     'isPlayer': True,
#     'isVerified': True,
#     'draftYear': 2012,
#     'mlbDebutDate': '2015-04-25',
#     'batSide': {'code': 'L', 'description': 'Left'},
#     'pitchHand': {'code': 'R', 'description': 'Right'},
#     'nameFirstLast': 'Max Muncy',
#     'nameSlug': 'max-muncy-571970',
#     'firstLastName': 'Max Muncy',
#     'lastFirstName': 'Muncy, Max',
#     'lastInitName': 'Muncy, M',
#     'initLastName': 'M Muncy',
#     'fullFMLName': 'Maxwell Steven Muncy',
#     'fullLFMName': 'Muncy, Maxwell Steven',
#     'strikeZoneTop': 3.02,
#     'strikeZoneBottom': 1.48},
#    'ID489334': {'id': 489334,
#     'fullName': 'Craig Stammen',
#     'link': '/api/v1/people/489334',
#     'firstName': 'Craig',
#     'lastName': 'Stammen',
#     'primaryNumber': '34',
#     'birthDate': '1984-03-09',
#     'currentAge': 40,
#     'birthCity': 'North Star',
#     'birthStateProvince': 'OH',
#     'birthCountry': 'USA',
#     'height': '6\' 2"',
#     'weight': 228,
#     'active': True,
#     'primaryPosition': {'code': '1',
#      'name': 'Pitcher',
#      'type': 'Pitcher',
#      'abbreviation': 'P'},
#     'useName': 'Craig',
#     'useLastName': 'Stammen',
#     'middleName': 'Nicholas',
#     'boxscoreName': 'Stammen',
#     'nickName': 'Trig',
#     'gender': 'M',
#     'isPlayer': True,
#     'isVerified': True,
#     'draftYear': 2005,
#     'pronunciation': 'STAM-en',
#     'mlbDebutDate': '2009-05-21',
#     'batSide': {'code': 'R', 'description': 'Right'},
#     'pitchHand': {'code': 'R', 'description': 'Right'},
#     'nameFirstLast': 'Craig Stammen',
#     'nameSlug': 'craig-stammen-489334',
#     'firstLastName': 'Craig Stammen',
#     'lastFirstName': 'Stammen, Craig',
#     'lastInitName': 'Stammen, C',
#     'initLastName': 'C Stammen',
#     'fullFMLName': 'Craig Nicholas Stammen',
#     'fullLFMName': 'Stammen, Craig Nicholas',
#     'strikeZoneTop': 3.467,
#     'strikeZoneBottom': 1.589},
#    'ID518692': {'id': 518692,
#     'fullName': 'Freddie Freeman',
#     'link': '/api/v1/people/518692',
#     'firstName': 'Frederick',
#     'lastName': 'Freeman',
#     'primaryNumber': '5',
#     'birthDate': '1989-09-12',
#     'currentAge': 35,
#     'birthCity': 'Villa Park',
#     'birthStateProvince': 'CA',
#     'birthCountry': 'USA',
#     'height': '6\' 5"',
#     'weight': 220,
#     'active': True,
#     'primaryPosition': {'code': '3',
#      'name': 'First Base',
#      'type': 'Infielder',
#      'abbreviation': '1B'},
#     'useName': 'Freddie',
#     'useLastName': 'Freeman',
#     'middleName': 'Charles',
#     'boxscoreName': 'Freeman, F',
#     'nickName': 'Phillip',
#     'gender': 'M',
#     'isPlayer': True,
#     'isVerified': True,
#     'draftYear': 2007,
#     'mlbDebutDate': '2010-09-01',
#     'batSide': {'code': 'L', 'description': 'Left'},
#     'pitchHand': {'code': 'R', 'description': 'Right'},
#     'nameFirstLast': 'Freddie Freeman',
#     'nameSlug': 'freddie-freeman-518692',
#     'firstLastName': 'Freddie Freeman',
#     'lastFirstName': 'Freeman, Freddie',
#     'lastInitName': 'Freeman, F',
#     'initLastName': 'F Freeman',
#     'fullFMLName': 'Frederick Charles Freeman',
#     'fullLFMName': 'Freeman, Frederick Charles',
#     'strikeZoneTop': 3.63,
#     'strikeZoneBottom': 1.78},
#    'ID607259': {'id': 607259,
#     'fullName': 'Nick Martinez',
#     'link': '/api/v1/people/607259',
#     'firstName': 'Nicholas',
#     'lastName': 'Martinez',
#     'primaryNumber': '28',
#     'birthDate': '1990-08-05',
#     'currentAge': 34,
#     'birthCity': 'Miami',
#     'birthStateProvince': 'FL',
#     'birthCountry': 'USA',
#     'height': '6\' 1"',
#     'weight': 200,
#     'active': True,
#     'primaryPosition': {'code': '1',
#      'name': 'Pitcher',
#      'type': 'Pitcher',
#      'abbreviation': 'P'},
#     'useName': 'Nick',
#     'useLastName': 'Martinez',
#     'middleName': 'Andres',
#     'boxscoreName': 'Martinez, N',
#     'nickName': 'Tricky',
#     'gender': 'M',
#     'isPlayer': True,
#     'isVerified': True,
#     'draftYear': 2011,
#     'mlbDebutDate': '2014-04-05',
#     'batSide': {'code': 'L', 'description': 'Left'},
#     'pitchHand': {'code': 'R', 'description': 'Right'},
#     'nameFirstLast': 'Nick Martinez',
#     'nameSlug': 'nick-martinez-607259',
#     'firstLastName': 'Nick Martinez',
#     'lastFirstName': 'Martinez, Nick',
#     'lastInitName': 'Martinez, N',
#     'initLastName': 'N Martinez',
#     'fullFMLName': 'Nicholas Andres Martinez',
#     'fullLFMName': 'Martinez, Nicholas Andres',
#     'strikeZoneTop': 3.411,
#     'strikeZoneBottom': 1.565},
#    'ID592390': {'id': 592390,
#     'fullName': 'Heath Hembree',
#     'link': '/api/v1/people/592390',
#     'firstName': 'Richard',
#     'lastName': 'Hembree',
#     'primaryNumber': '53',
#     'birthDate': '1989-01-13',
#     'currentAge': 35,
#     'birthCity': 'Spartanburg',
#     'birthStateProvince': 'SC',
#     'birthCountry': 'USA',
#     'height': '6\' 4"',
#     'weight': 220,
#     'active': True,
#     'primaryPosition': {'code': '1',
#      'name': 'Pitcher',
#      'type': 'Pitcher',
#      'abbreviation': 'P'},
#     'useName': 'Heath',
#     'useLastName': 'Hembree',
#     'middleName': 'Heath',
#     'boxscoreName': 'Hembree',
#     'nickName': 'Heater Here',
#     'gender': 'M',
#     'isPlayer': True,
#     'isVerified': True,
#     'draftYear': 2010,
#     'mlbDebutDate': '2013-09-03',
#     'batSide': {'code': 'R', 'description': 'Right'},
#     'pitchHand': {'code': 'R', 'description': 'Right'},
#     'nameFirstLast': 'Heath Hembree',
#     'nameSlug': 'heath-hembree-592390',
#     'firstLastName': 'Heath Hembree',
#     'lastFirstName': 'Hembree, Heath',
#     'lastInitName': 'Hembree, H',
#     'initLastName': 'H Hembree',
#     'fullFMLName': 'Richard Heath Hembree',
#     'fullLFMName': 'Hembree, Richard Heath',
#     'strikeZoneTop': 3.549,
#     'strikeZoneBottom': 1.627},
#    'ID670970': {'id': 670970,
#     'fullName': 'Adrian Morejon',
#     'link': '/api/v1/people/670970',
#     'firstName': 'Adrian',
#     'lastName': 'Morejon',
#     'primaryNumber': '50',
#     'birthDate': '1999-02-27',
#     'currentAge': 25,
#     'birthCity': 'Havana',
#     'birthCountry': 'Cuba',
#     'height': '5\' 11"',
#     'weight': 224,
#     'active': True,
#     'primaryPosition': {'code': '1',
#      'name': 'Pitcher',
#      'type': 'Pitcher',
#      'abbreviation': 'P'},
#     'useName': 'Adrian',
#     'useLastName': 'Morejon',
#     'boxscoreName': 'Morejon',
#     'nickName': 'More',
#     'gender': 'M',
#     'nameMatrilineal': 'Garcia',
#     'isPlayer': True,
#     'isVerified': True,
#     'pronunciation': 'more-eh-HONE',
#     'mlbDebutDate': '2019-07-21',
#     'batSide': {'code': 'L', 'description': 'Left'},
#     'pitchHand': {'code': 'L', 'description': 'Left'},
#     'nameFirstLast': 'Adrian Morejon',
#     'nameSlug': 'adrian-morejon-670970',
#     'firstLastName': 'Adrian Morejon',
#     'lastFirstName': 'Morejon, Adrian',
#     'lastInitName': 'Morejon, A',
#     'initLastName': 'A Morejon',
#     'fullFMLName': 'Adrian Morejon',
#     'fullLFMName': 'Morejon, Adrian',
#     'strikeZoneTop': 3.319,
#     'strikeZoneBottom': 1.513},
#    'ID592518': {'id': 592518,
#     'fullName': 'Manny Machado',
#     'link': '/api/v1/people/592518',
#     'firstName': 'Manuel',
#     'lastName': 'Machado',
#     'primaryNumber': '13',
#     'birthDate': '1992-07-06',
#     'currentAge': 32,
#     'birthCity': 'Miami',
#     'birthStateProvince': 'FL',
#     'birthCountry': 'USA',
#     'height': '6\' 3"',
#     'weight': 218,
#     'active': True,
#     'primaryPosition': {'code': '5',
#      'name': 'Third Base',
#      'type': 'Infielder',
#      'abbreviation': '3B'},
#     'useName': 'Manny',
#     'useLastName': 'Machado',
#     'middleName': 'Arturo',
#     'boxscoreName': 'Machado, M',
#     'nickName': 'El Ministro',
#     'gender': 'M',
#     'isPlayer': True,
#     'isVerified': True,
#     'draftYear': 2010,
#     'mlbDebutDate': '2012-08-09',
#     'batSide': {'code': 'R', 'description': 'Right'},
#     'pitchHand': {'code': 'R', 'description': 'Right'},
#     'nameFirstLast': 'Manny Machado',
#     'nameSlug': 'manny-machado-592518',
#     'firstLastName': 'Manny Machado',
#     'lastFirstName': 'Machado, Manny',
#     'lastInitName': 'Machado, M',
#     'initLastName': 'M Machado',
#     'fullFMLName': 'Manuel Arturo Machado',
#     'fullLFMName': 'Machado, Manuel Arturo',
#     'strikeZoneTop': 3.59,
#     'strikeZoneBottom': 1.62},
#    'ID593643': {'id': 593643,
#     'fullName': 'Hanser Alberto',
#     'link': '/api/v1/people/593643',
#     'firstName': 'Hanser',
#     'lastName': 'Alberto',
#     'primaryNumber': '26',
#     'birthDate': '1992-10-17',
#     'currentAge': 31,
#     'birthCity': 'San Francisco de Macoris',
#     'birthCountry': 'Dominican Republic',
#     'height': '5\' 11"',
#     'weight': 215,
#     'active': True,
#     'primaryPosition': {'code': '5',
#      'name': 'Third Base',
#      'type': 'Infielder',
#      'abbreviation': '3B'},
#     'useName': 'Hanser',
#     'useLastName': 'Alberto',
#     'middleName': 'Joel',
#     'boxscoreName': 'Alberto',
#     'nickName': '#Femalta',
#     'gender': 'M',
#     'nameMatrilineal': 'Pena',
#     'isPlayer': True,
#     'isVerified': False,
#     'pronunciation': 'HAWN-sair ahl-BAIR-toh',
#     'mlbDebutDate': '2015-05-29',
#     'batSide': {'code': 'R', 'description': 'Right'},
#     'pitchHand': {'code': 'R', 'description': 'Right'},
#     'nameFirstLast': 'Hanser Alberto',
#     'nameSlug': 'hanser-alberto-593643',
#     'firstLastName': 'Hanser Alberto',
#     'lastFirstName': 'Alberto, Hanser',
#     'lastInitName': 'Alberto, H',
#     'initLastName': 'H Alberto',
#     'fullFMLName': 'Hanser Joel Alberto',
#     'fullLFMName': 'Alberto, Hanser Joel',
#     'strikeZoneTop': 3.32,
#     'strikeZoneBottom': 1.53},
#    'ID628711': {'id': 628711,
#     'fullName': 'Julio Urías',
#     'link': '/api/v1/people/628711',
#     'firstName': 'Julio',
#     'lastName': 'Urías',
#     'primaryNumber': '7',
#     'birthDate': '1996-08-12',
#     'currentAge': 28,
#     'birthCity': 'Culiacan Rosales',
#     'birthStateProvince': 'Sinaloa',
#     'birthCountry': 'Mexico',
#     'height': '6\' 0"',
#     'weight': 225,
#     'active': True,
#     'primaryPosition': {'code': '1',
#      'name': 'Pitcher',
#      'type': 'Pitcher',
#      'abbreviation': 'P'},
#     'useName': 'Julio',
#     'useLastName': 'Urías',
#     'middleName': 'Cesar',
#     'boxscoreName': 'Urías, J',
#     'nickName': 'El Culichi',
#     'gender': 'M',
#     'isPlayer': True,
#     'isVerified': True,
#     'pronunciation': 'HOO-lee-oh oo-REE-ahs',
#     'mlbDebutDate': '2016-05-27',
#     'batSide': {'code': 'L', 'description': 'Left'},
#     'pitchHand': {'code': 'L', 'description': 'Left'},
#     'nameFirstLast': 'Julio Urías',
#     'nameSlug': 'julio-urias-628711',
#     'firstLastName': 'Julio Urías',
#     'lastFirstName': 'Urías, Julio',
#     'lastInitName': 'Urías, J',
#     'initLastName': 'J Urías',
#     'fullFMLName': 'Julio Cesar Urías',
#     'fullLFMName': 'Urías, Julio Cesar',
#     'strikeZoneTop': 3.35,
#     'strikeZoneBottom': 1.55},
#    'ID641355': {'id': 641355,
#     'fullName': 'Cody Bellinger',
#     'link': '/api/v1/people/641355',
#     'firstName': 'Cody',
#     'lastName': 'Bellinger',
#     'primaryNumber': '24',
#     'birthDate': '1995-07-13',
#     'currentAge': 29,
#     'birthCity': 'Scottsdale',
#     'birthStateProvince': 'AZ',
#     'birthCountry': 'USA',
#     'height': '6\' 4"',
#     'weight': 203,
#     'active': True,
#     'primaryPosition': {'code': '8',
#      'name': 'Outfielder',
#      'type': 'Outfielder',
#      'abbreviation': 'CF'},
#     'useName': 'Cody',
#     'useLastName': 'Bellinger',
#     'middleName': 'James',
#     'boxscoreName': 'Bellinger',
#     'nickName': 'Belli',
#     'gender': 'M',
#     'isPlayer': True,
#     'isVerified': True,
#     'draftYear': 2013,
#     'mlbDebutDate': '2017-04-25',
#     'batSide': {'code': 'L', 'description': 'Left'},
#     'pitchHand': {'code': 'L', 'description': 'Left'},
#     'nameFirstLast': 'Cody Bellinger',
#     'nameSlug': 'cody-bellinger-641355',
#     'firstLastName': 'Cody Bellinger',
#     'lastFirstName': 'Bellinger, Cody',
#     'lastInitName': 'Bellinger, C',
#     'initLastName': 'C Bellinger',
#     'fullFMLName': 'Cody James Bellinger',
#     'fullLFMName': 'Bellinger, Cody James',
#     'strikeZoneTop': 3.74,
#     'strikeZoneBottom': 1.76},
#    'ID623465': {'id': 623465,
#     'fullName': 'Evan Phillips',
#     'link': '/api/v1/people/623465',
#     'firstName': 'Evan',
#     'lastName': 'Phillips',
#     'primaryNumber': '59',
#     'birthDate': '1994-09-11',
#     'currentAge': 30,
#     'birthCity': 'Salisbury',
#     'birthStateProvince': 'MD',
#     'birthCountry': 'USA',
#     'height': '6\' 2"',
#     'weight': 215,
#     'active': True,
#     'primaryPosition': {'code': '1',
#      'name': 'Pitcher',
#      'type': 'Pitcher',
#      'abbreviation': 'P'},
#     'useName': 'Evan',
#     'useLastName': 'Phillips',
#     'middleName': 'John',
#     'boxscoreName': 'Phillips, E',
#     'nickName': 'Philly',
#     'gender': 'M',
#     'isPlayer': True,
#     'isVerified': True,
#     'draftYear': 2015,
#     'mlbDebutDate': '2018-07-03',
#     'batSide': {'code': 'R', 'description': 'Right'},
#     'pitchHand': {'code': 'R', 'description': 'Right'},
#     'nameFirstLast': 'Evan Phillips',
#     'nameSlug': 'evan-phillips-623465',
#     'firstLastName': 'Evan Phillips',
#     'lastFirstName': 'Phillips, Evan',
#     'lastInitName': 'Phillips, E',
#     'initLastName': 'E Phillips',
#     'fullFMLName': 'Evan John Phillips',
#     'fullLFMName': 'Phillips, Evan John',
#     'strikeZoneTop': 3.467,
#     'strikeZoneBottom': 1.589},
#    'ID666158': {'id': 666158,
#     'fullName': 'Gavin Lux',
#     'link': '/api/v1/people/666158',
#     'firstName': 'Gavin',
#     'lastName': 'Lux',
#     'primaryNumber': '9',
#     'birthDate': '1997-11-23',
#     'currentAge': 26,
#     'birthCity': 'Kenosha',
#     'birthStateProvince': 'WI',
#     'birthCountry': 'USA',
#     'height': '6\' 2"',
#     'weight': 190,
#     'active': True,
#     'primaryPosition': {'code': '4',
#      'name': 'Second Base',
#      'type': 'Infielder',
#      'abbreviation': '2B'},
#     'useName': 'Gavin',
#     'useLastName': 'Lux',
#     'middleName': 'Thomas',
#     'boxscoreName': 'Lux',
#     'gender': 'M',
#     'isPlayer': True,
#     'isVerified': False,
#     'draftYear': 2016,
#     'mlbDebutDate': '2019-09-02',
#     'batSide': {'code': 'L', 'description': 'Left'},
#     'pitchHand': {'code': 'R', 'description': 'Right'},
#     'nameFirstLast': 'Gavin Lux',
#     'nameSlug': 'gavin-lux-666158',
#     'firstLastName': 'Gavin Lux',
#     'lastFirstName': 'Lux, Gavin',
#     'lastInitName': 'Lux, G',
#     'initLastName': 'G Lux',
#     'fullFMLName': 'Gavin Thomas Lux',
#     'fullLFMName': 'Lux, Gavin Thomas',
#     'strikeZoneTop': 3.25,
#     'strikeZoneBottom': 1.53},
#    'ID477132': {'id': 477132,
#     'fullName': 'Clayton Kershaw',
#     'link': '/api/v1/people/477132',
#     'firstName': 'Clayton',
#     'lastName': 'Kershaw',
#     'primaryNumber': '22',
#     'birthDate': '1988-03-19',
#     'currentAge': 36,
#     'birthCity': 'Dallas',
#     'birthStateProvince': 'TX',
#     'birthCountry': 'USA',
#     'height': '6\' 4"',
#     'weight': 225,
#     'active': True,
#     'primaryPosition': {'code': '1',
#      'name': 'Pitcher',
#      'type': 'Pitcher',
#      'abbreviation': 'P'},
#     'useName': 'Clayton',
#     'useLastName': 'Kershaw',
#     'middleName': 'Edward',
#     'boxscoreName': 'Kershaw',
#     'nickName': 'Kersh',
#     'gender': 'M',
#     'isPlayer': True,
#     'isVerified': True,
#     'draftYear': 2006,
#     'mlbDebutDate': '2008-05-25',
#     'batSide': {'code': 'L', 'description': 'Left'},
#     'pitchHand': {'code': 'L', 'description': 'Left'},
#     'nameFirstLast': 'Clayton Kershaw',
#     'nameSlug': 'clayton-kershaw-477132',
#     'firstLastName': 'Clayton Kershaw',
#     'lastFirstName': 'Kershaw, Clayton',
#     'lastInitName': 'Kershaw, C',
#     'initLastName': 'C Kershaw',
#     'fullFMLName': 'Clayton Edward Kershaw',
#     'fullLFMName': 'Kershaw, Clayton Edward',
#     'strikeZoneTop': 3.36,
#     'strikeZoneBottom': 1.6},
#    'ID572204': {'id': 572204,
#     'fullName': 'Trayce Thompson',
#     'link': '/api/v1/people/572204',
#     'firstName': 'Trayce',
#     'lastName': 'Thompson',
#     'primaryNumber': '30',
#     'birthDate': '1991-03-15',
#     'currentAge': 33,
#     'birthCity': 'Los Angeles',
#     'birthStateProvince': 'CA',
#     'birthCountry': 'USA',
#     'height': '6\' 2"',
#     'weight': 225,
#     'active': True,
#     'primaryPosition': {'code': '9',
#      'name': 'Outfielder',
#      'type': 'Outfielder',
#      'abbreviation': 'RF'},
#     'useName': 'Trayce',
#     'useLastName': 'Thompson',
#     'middleName': 'Nikolas',
#     'boxscoreName': 'Thompson, T',
#     'nickName': "Rocco's Uncle",
#     'gender': 'M',
#     'isPlayer': True,
#     'isVerified': True,
#     'draftYear': 2009,
#     'mlbDebutDate': '2015-08-04',
#     'batSide': {'code': 'R', 'description': 'Right'},
#     'pitchHand': {'code': 'R', 'description': 'Right'},
#     'nameFirstLast': 'Trayce Thompson',
#     'nameSlug': 'trayce-thompson-572204',
#     'firstLastName': 'Trayce Thompson',
#     'lastFirstName': 'Thompson, Trayce',
#     'lastInitName': 'Thompson, T',
#     'initLastName': 'T Thompson',
#     'fullFMLName': 'Trayce Nikolas Thompson',
#     'fullLFMName': 'Thompson, Trayce Nikolas',
#     'strikeZoneTop': 3.34,
#     'strikeZoneBottom': 1.66},
#    'ID665742': {'id': 665742,
#     'fullName': 'Juan Soto',
#     'link': '/api/v1/people/665742',
#     'firstName': 'Juan',
#     'lastName': 'Soto',
#     'primaryNumber': '22',
#     'birthDate': '1998-10-25',
#     'currentAge': 25,
#     'birthCity': 'Santo Domingo',
#     'birthCountry': 'Dominican Republic',
#     'height': '6\' 2"',
#     'weight': 224,
#     'active': True,
#     'primaryPosition': {'code': '9',
#      'name': 'Outfielder',
#      'type': 'Outfielder',
#      'abbreviation': 'RF'},
#     'useName': 'Juan',
#     'useLastName': 'Soto',
#     'middleName': 'Jose',
#     'boxscoreName': 'Soto, J',
#     'nickName': 'Soto Pacheco',
#     'gender': 'M',
#     'nameMatrilineal': 'Pacheco',
#     'isPlayer': True,
#     'isVerified': True,
#     'mlbDebutDate': '2018-05-15',
#     'batSide': {'code': 'L', 'description': 'Left'},
#     'pitchHand': {'code': 'L', 'description': 'Left'},
#     'nameFirstLast': 'Juan Soto',
#     'nameSlug': 'juan-soto-665742',
#     'firstLastName': 'Juan Soto',
#     'lastFirstName': 'Soto, Juan',
#     'lastInitName': 'Soto, J',
#     'initLastName': 'J Soto',
#     'fullFMLName': 'Juan Jose Soto',
#     'fullLFMName': 'Soto, Juan Jose',
#     'strikeZoneTop': 3.06,
#     'strikeZoneBottom': 1.51},
#    'ID605483': {'id': 605483,
#     'fullName': 'Blake Snell',
#     'link': '/api/v1/people/605483',
#     'firstName': 'Blake',
#     'lastName': 'Snell',
#     'primaryNumber': '7',
#     'birthDate': '1992-12-04',
#     'currentAge': 31,
#     'birthCity': 'Seattle',
#     'birthStateProvince': 'WA',
#     'birthCountry': 'USA',
#     'height': '6\' 4"',
#     'weight': 225,
#     'active': True,
#     'primaryPosition': {'code': '1',
#      'name': 'Pitcher',
#      'type': 'Pitcher',
#      'abbreviation': 'P'},
#     'useName': 'Blake',
#     'useLastName': 'Snell',
#     'middleName': 'Ashton',
#     'boxscoreName': 'Snell',
#     'nickName': 'Zilla',
#     'gender': 'M',
#     'isPlayer': True,
#     'isVerified': True,
#     'draftYear': 2011,
#     'mlbDebutDate': '2016-04-23',
#     'batSide': {'code': 'L', 'description': 'Left'},
#     'pitchHand': {'code': 'L', 'description': 'Left'},
#     'nameFirstLast': 'Blake Snell',
#     'nameSlug': 'blake-snell-605483',
#     'firstLastName': 'Blake Snell',
#     'lastFirstName': 'Snell, Blake',
#     'lastInitName': 'Snell, B',
#     'initLastName': 'B Snell',
#     'fullFMLName': 'Blake Ashton Snell',
#     'fullLFMName': 'Snell, Blake Ashton',
#     'strikeZoneTop': 3.77,
#     'strikeZoneBottom': 1.74},
#    'ID571760': {'id': 571760,
#     'fullName': 'Andrew Heaney',
#     'link': '/api/v1/people/571760',
#     'firstName': 'Andrew',
#     'lastName': 'Heaney',
#     'primaryNumber': '44',
#     'birthDate': '1991-06-05',
#     'currentAge': 33,
#     'birthCity': 'Oklahoma City',
#     'birthStateProvince': 'OK',
#     'birthCountry': 'USA',
#     'height': '6\' 2"',
#     'weight': 200,
#     'active': True,
#     'primaryPosition': {'code': '1',
#      'name': 'Pitcher',
#      'type': 'Pitcher',
#      'abbreviation': 'P'},
#     'useName': 'Andrew',
#     'useLastName': 'Heaney',
#     'middleName': 'M.',
#     'boxscoreName': 'Heaney',
#     'nickName': 'Heandog',
#     'gender': 'M',
#     'isPlayer': True,
#     'isVerified': True,
#     'draftYear': 2012,
#     'pronunciation': 'HEE-nee',
#     'mlbDebutDate': '2014-06-19',
#     'batSide': {'code': 'L', 'description': 'Left'},
#     'pitchHand': {'code': 'L', 'description': 'Left'},
#     'nameFirstLast': 'Andrew Heaney',
#     'nameSlug': 'andrew-heaney-571760',
#     'firstLastName': 'Andrew Heaney',
#     'lastFirstName': 'Heaney, Andrew',
#     'lastInitName': 'Heaney, A',
#     'initLastName': 'A Heaney',
#     'fullFMLName': 'Andrew M. Heaney',
#     'fullLFMName': 'Heaney, Andrew M.',
#     'strikeZoneTop': 3.467,
#     'strikeZoneBottom': 1.589},
#    'ID663757': {'id': 663757,
#     'fullName': 'Trent Grisham',
#     'link': '/api/v1/people/663757',
#     'firstName': 'Trenton',
#     'lastName': 'Grisham',
#     'primaryNumber': '12',
#     'birthDate': '1996-11-01',
#     'currentAge': 27,
#     'birthCity': 'Burleson',
#     'birthStateProvince': 'TX',
#     'birthCountry': 'USA',
#     'height': '5\' 11"',
#     'weight': 224,
#     'active': True,
#     'primaryPosition': {'code': '8',
#      'name': 'Outfielder',
#      'type': 'Outfielder',
#      'abbreviation': 'CF'},
#     'useName': 'Trent',
#     'useLastName': 'Grisham',
#     'middleName': 'Marcus',
#     'boxscoreName': 'Grisham',
#     'nickName': 'Grish',
#     'gender': 'M',
#     'isPlayer': True,
#     'isVerified': True,
#     'draftYear': 2015,
#     'pronunciation': 'GRISH-um',
#     'mlbDebutDate': '2019-08-01',
#     'batSide': {'code': 'L', 'description': 'Left'},
#     'pitchHand': {'code': 'L', 'description': 'Left'},
#     'nameFirstLast': 'Trent Grisham',
#     'nameSlug': 'trent-grisham-663757',
#     'firstLastName': 'Trent Grisham',
#     'lastFirstName': 'Grisham, Trent',
#     'lastInitName': 'Grisham, T',
#     'initLastName': 'T Grisham',
#     'fullFMLName': 'Trenton Marcus Grisham',
#     'fullLFMName': 'Grisham, Trenton Marcus',
#     'strikeZoneTop': 3.52,
#     'strikeZoneBottom': 1.74},
#    'ID630105': {'id': 630105,
#     'fullName': 'Jake Cronenworth',
#     'link': '/api/v1/people/630105',
#     'firstName': 'Jacob',
#     'lastName': 'Cronenworth',
#     'primaryNumber': '9',
#     'birthDate': '1994-01-21',
#     'currentAge': 30,
#     'birthCity': 'St. Clair',
#     'birthStateProvince': 'MI',
#     'birthCountry': 'USA',
#     'height': '6\' 0"',
#     'weight': 187,
#     'active': True,
#     'primaryPosition': {'code': '3',
#      'name': 'First Base',
#      'type': 'Infielder',
#      'abbreviation': '1B'},
#     'useName': 'Jake',
#     'useLastName': 'Cronenworth',
#     'middleName': 'John',
#     'boxscoreName': 'Cronenworth',
#     'gender': 'M',
#     'isPlayer': True,
#     'isVerified': True,
#     'draftYear': 2015,
#     'pronunciation': 'CROW-nen-worth',
#     'mlbDebutDate': '2020-07-26',
#     'batSide': {'code': 'L', 'description': 'Left'},
#     'pitchHand': {'code': 'R', 'description': 'Right'},
#     'nameFirstLast': 'Jake Cronenworth',
#     'nameSlug': 'jake-cronenworth-630105',
#     'firstLastName': 'Jake Cronenworth',
#     'lastFirstName': 'Cronenworth, Jake',
#     'lastInitName': 'Cronenworth, J',
#     'initLastName': 'J Cronenworth',
#     'fullFMLName': 'Jacob John Cronenworth',
#     'fullLFMName': 'Cronenworth, Jacob John',
#     'strikeZoneTop': 3.29,
#     'strikeZoneBottom': 1.55},
#    'ID543592': {'id': 543592,
#     'fullName': 'Austin Nola',
#     'link': '/api/v1/people/543592',
#     'firstName': 'Austin',
#     'lastName': 'Nola',
#     'primaryNumber': '14',
#     'birthDate': '1989-12-28',
#     'currentAge': 34,
#     'birthCity': 'Baton Rouge',
#     'birthStateProvince': 'LA',
#     'birthCountry': 'USA',
#     'height': '6\' 0"',
#     'weight': 197,
#     'active': True,
#     'primaryPosition': {'code': '2',
#      'name': 'Catcher',
#      'type': 'Catcher',
#      'abbreviation': 'C'},
#     'useName': 'Austin',
#     'useLastName': 'Nola',
#     'middleName': 'Kyle',
#     'boxscoreName': 'Nola, Au',
#     'gender': 'M',
#     'isPlayer': True,
#     'isVerified': True,
#     'draftYear': 2012,
#     'mlbDebutDate': '2019-06-16',
#     'batSide': {'code': 'R', 'description': 'Right'},
#     'pitchHand': {'code': 'R', 'description': 'Right'},
#     'nameFirstLast': 'Austin Nola',
#     'nameSlug': 'austin-nola-543592',
#     'firstLastName': 'Austin Nola',
#     'lastFirstName': 'Nola, Austin',
#     'lastInitName': 'Nola, A',
#     'initLastName': 'A Nola',
#     'fullFMLName': 'Austin Kyle Nola',
#     'fullLFMName': 'Nola, Austin Kyle',
#     'strikeZoneTop': 3.5,
#     'strikeZoneBottom': 1.63},
#    'ID595751': {'id': 595751,
#     'fullName': 'Jorge Alfaro',
#     'link': '/api/v1/people/595751',
#     'firstName': 'Jorge',
#     'lastName': 'Alfaro',
#     'primaryNumber': '32',
#     'birthDate': '1993-06-11',
#     'currentAge': 31,
#     'birthCity': 'Sincelejo',
#     'birthCountry': 'Colombia',
#     'height': '6\' 2"',
#     'weight': 249,
#     'active': True,
#     'primaryPosition': {'code': '2',
#      'name': 'Catcher',
#      'type': 'Catcher',
#      'abbreviation': 'C'},
#     'useName': 'Jorge',
#     'useLastName': 'Alfaro',
#     'middleName': 'Mario',
#     'boxscoreName': 'Alfaro',
#     'nickName': 'El Oso',
#     'gender': 'M',
#     'nameMatrilineal': 'Buelvas',
#     'isPlayer': True,
#     'isVerified': True,
#     'pronunciation': 'HOR-heh al-FAR-oh',
#     'mlbDebutDate': '2016-09-12',
#     'batSide': {'code': 'R', 'description': 'Right'},
#     'pitchHand': {'code': 'R', 'description': 'Right'},
#     'nameFirstLast': 'Jorge Alfaro',
#     'nameSlug': 'jorge-alfaro-595751',
#     'firstLastName': 'Jorge Alfaro',
#     'lastFirstName': 'Alfaro, Jorge',
#     'lastInitName': 'Alfaro, J',
#     'initLastName': 'J Alfaro',
#     'fullFMLName': 'Jorge Mario Alfaro',
#     'fullLFMName': 'Alfaro, Jorge Mario',
#     'strikeZoneTop': 3.34,
#     'strikeZoneBottom': 1.56},
#    'ID678246': {'id': 678246,
#     'fullName': 'Miguel Vargas',
#     'link': '/api/v1/people/678246',
#     'firstName': 'Miguel',
#     'lastName': 'Vargas',
#     'primaryNumber': '20',
#     'birthDate': '1999-11-17',
#     'currentAge': 24,
#     'birthCity': 'La Habana',
#     'birthCountry': 'Cuba',
#     'height': '6\' 2"',
#     'weight': 205,
#     'active': True,
#     'primaryPosition': {'code': '5',
#      'name': 'Third Base',
#      'type': 'Infielder',
#      'abbreviation': '3B'},
#     'useName': 'Miguel',
#     'useLastName': 'Vargas',
#     'middleName': 'Antonio',
#     'boxscoreName': 'Vargas, M',
#     'gender': 'M',
#     'nameMatrilineal': 'Echarry',
#     'isPlayer': True,
#     'isVerified': True,
#     'mlbDebutDate': '2022-08-03',
#     'batSide': {'code': 'R', 'description': 'Right'},
#     'pitchHand': {'code': 'R', 'description': 'Right'},
#     'nameFirstLast': 'Miguel Vargas',
#     'nameSlug': 'miguel-vargas-678246',
#     'firstLastName': 'Miguel Vargas',
#     'lastFirstName': 'Vargas, Miguel',
#     'lastInitName': 'Vargas, M',
#     'initLastName': 'M Vargas',
#     'fullFMLName': 'Miguel Antonio Vargas',
#     'fullLFMName': 'Vargas, Miguel Antonio',
#     'strikeZoneTop': 3.26,
#     'strikeZoneBottom': 1.55},
#    'ID455119': {'id': 455119,
#     'fullName': 'Chris Martin',
#     'link': '/api/v1/people/455119',
#     'firstName': 'Christopher',
#     'lastName': 'Martin',
#     'primaryNumber': '55',
#     'birthDate': '1986-06-02',
#     'currentAge': 38,
#     'birthCity': 'Arlington',
#     'birthStateProvince': 'TX',
#     'birthCountry': 'USA',
#     'height': '6\' 8"',
#     'weight': 224,
#     'active': True,
#     'primaryPosition': {'code': '1',
#      'name': 'Pitcher',
#      'type': 'Pitcher',
#      'abbreviation': 'P'},
#     'useName': 'Chris',
#     'useLastName': 'Martin',
#     'middleName': 'Riley',
#     'boxscoreName': 'Martin',
#     'nickName': 'C-Mart',
#     'gender': 'M',
#     'isPlayer': True,
#     'isVerified': True,
#     'draftYear': 2005,
#     'mlbDebutDate': '2014-04-26',
#     'batSide': {'code': 'R', 'description': 'Right'},
#     'pitchHand': {'code': 'R', 'description': 'Right'},
#     'nameFirstLast': 'Chris Martin',
#     'nameSlug': 'chris-martin-455119',
#     'firstLastName': 'Chris Martin',
#     'lastFirstName': 'Martin, Chris',
#     'lastInitName': 'Martin, C',
#     'initLastName': 'C Martin',
#     'fullFMLName': 'Christopher Riley Martin',
#     'fullLFMName': 'Martin, Christopher Riley',
#     'strikeZoneTop': 3.688,
#     'strikeZoneBottom': 1.747},
#    'ID640492': {'id': 640492,
#     'fullName': 'José Azocar',
#     'link': '/api/v1/people/640492',
#     'firstName': 'José',
#     'lastName': 'Azocar',
#     'birthDate': '1996-05-11',
#     'currentAge': 28,
#     'birthCity': 'Guiria',
#     'birthCountry': 'Venezuela',
#     'height': '5\' 11"',
#     'weight': 181,
#     'active': True,
#     'primaryPosition': {'code': '7',
#      'name': 'Outfielder',
#      'type': 'Outfielder',
#      'abbreviation': 'LF'},
#     'useName': 'José',
#     'useLastName': 'Azocar',
#     'middleName': 'Enrique',
#     'boxscoreName': 'Azocar',
#     'gender': 'M',
#     'nameMatrilineal': 'Perez',
#     'isPlayer': True,
#     'isVerified': False,
#     'mlbDebutDate': '2022-04-07',
#     'batSide': {'code': 'R', 'description': 'Right'},
#     'pitchHand': {'code': 'R', 'description': 'Right'},
#     'nameFirstLast': 'José Azocar',
#     'nameSlug': 'jose-azocar-640492',
#     'firstLastName': 'José Azocar',
#     'lastFirstName': 'Azocar, José',
#     'lastInitName': 'Azocar, J',
#     'initLastName': 'J Azocar',
#     'fullFMLName': 'José Enrique Azocar',
#     'fullLFMName': 'Azocar, José Enrique',
#     'strikeZoneTop': 3.29,
#     'strikeZoneBottom': 1.59},
#    'ID621051': {'id': 621051,
#     'fullName': 'Steven Wilson',
#     'link': '/api/v1/people/621051',
#     'firstName': 'Steven',
#     'lastName': 'Wilson',
#     'primaryNumber': '36',
#     'birthDate': '1994-08-24',
#     'currentAge': 30,
#     'birthCity': 'Littleton',
#     'birthStateProvince': 'CO',
#     'birthCountry': 'USA',
#     'height': '6\' 3"',
#     'weight': 221,
#     'active': True,
#     'primaryPosition': {'code': '1',
#      'name': 'Pitcher',
#      'type': 'Pitcher',
#      'abbreviation': 'P'},
#     'useName': 'Steven',
#     'useLastName': 'Wilson',
#     'middleName': 'Christopher',
#     'boxscoreName': 'Wilson, S',
#     'gender': 'M',
#     'isPlayer': True,
#     'isVerified': True,
#     'draftYear': 2018,
#     'mlbDebutDate': '2022-04-09',
#     'batSide': {'code': 'R', 'description': 'Right'},
#     'pitchHand': {'code': 'R', 'description': 'Right'},
#     'nameFirstLast': 'Steven Wilson',
#     'nameSlug': 'steven-wilson-621051',
#     'firstLastName': 'Steven Wilson',
#     'lastFirstName': 'Wilson, Steven',
#     'lastInitName': 'Wilson, S',
#     'initLastName': 'S Wilson',
#     'fullFMLName': 'Steven Christopher Wilson',
#     'fullLFMName': 'Wilson, Steven Christopher',
#     'strikeZoneTop': 3.49,
#     'strikeZoneBottom': 1.601},
#    'ID572955': {'id': 572955,
#     'fullName': 'Pierce Johnson',
#     'link': '/api/v1/people/572955',
#     'firstName': 'Pierce',
#     'lastName': 'Johnson',
#     'primaryNumber': '38',
#     'birthDate': '1991-05-10',
#     'currentAge': 33,
#     'birthCity': 'Denver',
#     'birthStateProvince': 'CO',
#     'birthCountry': 'USA',
#     'height': '6\' 2"',
#     'weight': 202,
#     'active': True,
#     'primaryPosition': {'code': '1',
#      'name': 'Pitcher',
#      'type': 'Pitcher',
#      'abbreviation': 'P'},
#     'useName': 'Pierce',
#     'useLastName': 'Johnson',
#     'middleName': 'William',
#     'boxscoreName': 'Johnson',
#     'nickName': 'P.J.',
#     'gender': 'M',
#     'isPlayer': True,
#     'isVerified': True,
#     'draftYear': 2012,
#     'mlbDebutDate': '2017-05-19',
#     'batSide': {'code': 'R', 'description': 'Right'},
#     'pitchHand': {'code': 'R', 'description': 'Right'},
#     'nameFirstLast': 'Pierce Johnson',
#     'nameSlug': 'pierce-johnson-572955',
#     'firstLastName': 'Pierce Johnson',
#     'lastFirstName': 'Johnson, Pierce',
#     'lastInitName': 'Johnson, P',
#     'initLastName': 'P Johnson',
#     'fullFMLName': 'Pierce William Johnson',
#     'fullLFMName': 'Johnson, Pierce William',
#     'strikeZoneTop': 3.467,
#     'strikeZoneBottom': 1.589},
#    'ID681911': {'id': 681911,
#     'fullName': 'Alex Vesia',
#     'link': '/api/v1/people/681911',
#     'firstName': 'Alexander',
#     'lastName': 'Vesia',
#     'primaryNumber': '51',
#     'birthDate': '1996-04-11',
#     'currentAge': 28,
#     'birthCity': 'Alpine',
#     'birthStateProvince': 'CA',
#     'birthCountry': 'USA',
#     'height': '6\' 1"',
#     'weight': 209,
#     'active': True,
#     'primaryPosition': {'code': '1',
#      'name': 'Pitcher',
#      'type': 'Pitcher',
#      'abbreviation': 'P'},
#     'useName': 'Alex',
#     'useLastName': 'Vesia',
#     'middleName': 'Victor',
#     'boxscoreName': 'Vesia',
#     'gender': 'M',
#     'isPlayer': True,
#     'isVerified': False,
#     'draftYear': 2018,
#     'pronunciation': 'vaSEEYA',
#     'mlbDebutDate': '2020-07-25',
# ...
#      'value': 'Heaney 21; Vesia 3; Martin 5; Jackson 8; Musgrove 23; Suarez, Ro 2; García, L 4; Hill, T 3; Stammen 5; Myers 4.'},
#     {'label': 'Inherited runners-scored',
#      'value': 'Suarez, Ro 2-0; Hill, T 2-1; Stammen 3-3.'},
#     {'label': 'Umpires',
#      'value': 'HP: Dan Iassogna. 1B: Junior Valentine. 2B: Jim Wolf. 3B: Ben May. '},
#     {'label': 'Weather', 'value': '83 degrees, Sunny.'},
#     {'label': 'Wind', 'value': '7 mph, L To R.'},
#     {'label': 'First pitch', 'value': '1:12 PM.'},
#     {'label': 'T', 'value': '3:01.'},
#     {'label': 'Att', 'value': '41,652.'},
#     {'label': 'Venue', 'value': 'Petco Park.'},
#     {'label': 'September 11, 2022'}],
#    'pitchingNotes': [],
#    'topPerformers': [{'player': {'person': {'id': 457759,
#        'fullName': 'Justin Turner',
#        'link': '/api/v1/people/457759'},
#       'jerseyNumber': '10',
#       'position': {'code': '5',
#        'name': 'Third Base',
#        'type': 'Infielder',
#        'abbreviation': '3B'},
#       'status': {'code': 'A', 'description': 'Active'},
#       'parentTeamId': 119,
#       'battingOrder': '600',
#       'stats': {'batting': {'summary': '2-4 | 2 HR, 5 RBI, 2 R',
#         'gamesPlayed': 1,
#         'flyOuts': 2,
#         'groundOuts': 0,
#         'airOuts': 2,
#         'runs': 2,
#         'doubles': 0,
#         'triples': 0,
#         'homeRuns': 2,
#         'strikeOuts': 0,
#         'baseOnBalls': 0,
#         'intentionalWalks': 0,
#         'hits': 2,
#         'hitByPitch': 0,
#         'atBats': 4,
#         'caughtStealing': 0,
#         'stolenBases': 0,
#         'stolenBasePercentage': '.---',
#         'groundIntoDoublePlay': 0,
#         'groundIntoTriplePlay': 0,
#         'plateAppearances': 4,
#         'totalBases': 8,
#         'rbi': 5,
#         'leftOnBase': 2,
#         'sacBunts': 0,
#         'sacFlies': 0,
#         'catchersInterference': 0,
#         'pickoffs': 0,
#         'atBatsPerHomeRun': '2.00',
#         'popOuts': 0,
#         'lineOuts': 0},
#        'pitching': {},
#        'fielding': {'gamesStarted': 1,
#         'caughtStealing': 0,
#         'stolenBases': 0,
#         'stolenBasePercentage': '.---',
#         'assists': 1,
#         'putOuts': 0,
#         'errors': 0,
#         'chances': 1,
#         'fielding': '.000',
#         'passedBall': 0,
#         'pickoffs': 0}},
#       'seasonStats': {'batting': {'gamesPlayed': 113,
#         'flyOuts': 92,
#         'groundOuts': 85,
#         'airOuts': 144,
#         'runs': 56,
#         'doubles': 32,
#         'triples': 0,
#         'homeRuns': 13,
#         'strikeOuts': 77,
#         'baseOnBalls': 45,
#         'intentionalWalks': 1,
#         'hits': 114,
#         'hitByPitch': 5,
#         'avg': '.277',
#         'atBats': 412,
#         'obp': '.349',
#         'slg': '.449',
#         'ops': '.798',
#         'caughtStealing': 0,
#         'stolenBases': 3,
#         'stolenBasePercentage': '1.000',
#         'groundIntoDoublePlay': 12,
#         'groundIntoTriplePlay': 0,
#         'plateAppearances': 470,
#         'totalBases': 185,
#         'rbi': 78,
#         'leftOnBase': 178,
#         'sacBunts': 0,
#         'sacFlies': 8,
#         'babip': '.306',
#         'groundOutsToAirouts': '0.59',
#         'catchersInterference': 0,
#         'pickoffs': 0,
#         'atBatsPerHomeRun': '31.69',
#         'popOuts': 20,
#         'lineOuts': 32},
#        'pitching': {'gamesPlayed': 0,
#         'gamesStarted': 0,
#         'flyOuts': 0,
#         'groundOuts': 0,
#         'airOuts': 0,
#         'runs': 0,
#         'doubles': 0,
#         'triples': 0,
#         'homeRuns': 0,
#         'strikeOuts': 0,
#         'baseOnBalls': 0,
#         'intentionalWalks': 0,
#         'hits': 0,
#         'hitByPitch': 0,
#         'atBats': 0,
#         'obp': '.000',
#         'caughtStealing': 0,
#         'stolenBases': 0,
#         'stolenBasePercentage': '.---',
#         'numberOfPitches': 0,
#         'era': '-.--',
#         'inningsPitched': '0.0',
#         'wins': 0,
#         'losses': 0,
#         'saves': 0,
#         'saveOpportunities': 0,
#         'holds': 0,
#         'blownSaves': 0,
#         'earnedRuns': 0,
#         'whip': '-',
#         'battersFaced': 0,
#         'outs': 0,
#         'gamesPitched': 0,
#         'completeGames': 0,
#         'shutouts': 0,
#         'balls': 0,
#         'strikes': 0,
#         'strikePercentage': '-.--',
#         'hitBatsmen': 0,
#         'balks': 0,
#         'wildPitches': 0,
#         'pickoffs': 0,
#         'groundOutsToAirouts': '-.--',
#         'rbi': 0,
#         'winPercentage': '.---',
#         'pitchesPerInning': '-.--',
#         'gamesFinished': 0,
#         'strikeoutWalkRatio': '-.--',
#         'strikeoutsPer9Inn': '-.--',
#         'walksPer9Inn': '-.--',
#         'hitsPer9Inn': '-.--',
#         'runsScoredPer9': '-.--',
#         'homeRunsPer9': '-.--',
#         'inheritedRunners': 0,
#         'inheritedRunnersScored': 0,
#         'catchersInterference': 0,
#         'sacBunts': 0,
#         'sacFlies': 0,
#         'passedBall': 0,
#         'popOuts': 0,
#         'lineOuts': 0},
#        'fielding': {'gamesStarted': 1,
#         'caughtStealing': 0,
#         'stolenBases': 0,
#         'stolenBasePercentage': '.---',
#         'assists': 129,
#         'putOuts': 31,
#         'errors': 6,
#         'chances': 166,
#         'fielding': '.964',
#         'passedBall': 0,
#         'pickoffs': 0}},
#       'gameStatus': {'isCurrentBatter': False,
#        'isCurrentPitcher': False,
#        'isOnBench': False,
#        'isSubstitute': False},
#       'allPositions': [{'code': '5',
#         'name': 'Third Base',
#         'type': 'Infielder',
#         'abbreviation': '3B'}]},
#      'type': 'hitter',
#      'gameScore': 72,
#      'hittingGameScore': 72},
#     {'player': {'person': {'id': 607208,
#        'fullName': 'Trea Turner',
#        'link': '/api/v1/people/607208'},
#       'jerseyNumber': '6',
#       'position': {'code': '6',
#        'name': 'Shortstop',
#        'type': 'Infielder',
#        'abbreviation': 'SS'},
#       'status': {'code': 'A', 'description': 'Active'},
#       'parentTeamId': 119,
#       'battingOrder': '200',
#       'stats': {'batting': {'summary': '2-5 | HR, K, 2 RBI',
#         'gamesPlayed': 1,
#         'flyOuts': 1,
#         'groundOuts': 1,
#         'airOuts': 1,
#         'runs': 2,
#         'doubles': 0,
#         'triples': 0,
#         'homeRuns': 1,
#         'strikeOuts': 1,
#         'baseOnBalls': 0,
#         'intentionalWalks': 0,
#         'hits': 2,
#         'hitByPitch': 0,
#         'atBats': 5,
#         'caughtStealing': 0,
#         'stolenBases': 0,
#         'stolenBasePercentage': '.---',
#         'groundIntoDoublePlay': 0,
#         'groundIntoTriplePlay': 0,
#         'plateAppearances': 5,
#         'totalBases': 5,
#         'rbi': 2,
#         'leftOnBase': 1,
#         'sacBunts': 0,
#         'sacFlies': 0,
#         'catchersInterference': 0,
#         'pickoffs': 0,
#         'atBatsPerHomeRun': '5.00',
#         'popOuts': 0,
#         'lineOuts': 0},
#        'pitching': {},
#        'fielding': {'gamesStarted': 1,
#         'caughtStealing': 0,
#         'stolenBases': 0,
#         'stolenBasePercentage': '.---',
#         'assists': 1,
#         'putOuts': 0,
#         'errors': 0,
#         'chances': 1,
#         'fielding': '.000',
#         'passedBall': 0,
#         'pickoffs': 0}},
#       'seasonStats': {'batting': {'gamesPlayed': 138,
#         'flyOuts': 87,
#         'groundOuts': 141,
#         'airOuts': 146,
#         'runs': 90,
#         'doubles': 36,
#         'triples': 3,
#         'homeRuns': 20,
#         'strikeOuts': 111,
#         'baseOnBalls': 39,
#         'intentionalWalks': 1,
#         'hits': 173,
#         'hitByPitch': 3,
#         'avg': '.306',
#         'atBats': 565,
#         'obp': '.351',
#         'slg': '.487',
#         'ops': '.838',
#         'caughtStealing': 3,
#         'stolenBases': 24,
#         'stolenBasePercentage': '.889',
#         'groundIntoDoublePlay': 9,
#         'groundIntoTriplePlay': 0,
#         'plateAppearances': 615,
#         'totalBases': 275,
#         'rbi': 96,
#         'leftOnBase': 234,
#         'sacBunts': 0,
#         'sacFlies': 6,
#         'babip': '.348',
#         'groundOutsToAirouts': '0.97',
#         'catchersInterference': 2,
#         'pickoffs': 0,
#         'atBatsPerHomeRun': '28.25',
#         'popOuts': 23,
#         'lineOuts': 36},
#        'pitching': {'gamesPlayed': 0,
#         'gamesStarted': 0,
#         'flyOuts': 0,
#         'groundOuts': 0,
#         'airOuts': 0,
#         'runs': 0,
#         'doubles': 0,
#         'triples': 0,
#         'homeRuns': 0,
#         'strikeOuts': 0,
#         'baseOnBalls': 0,
#         'intentionalWalks': 0,
#         'hits': 0,
#         'hitByPitch': 0,
#         'atBats': 0,
#         'obp': '.000',
#         'caughtStealing': 0,
#         'stolenBases': 0,
#         'stolenBasePercentage': '.---',
#         'numberOfPitches': 0,
#         'era': '-.--',
#         'inningsPitched': '0.0',
#         'wins': 0,
#         'losses': 0,
#         'saves': 0,
#         'saveOpportunities': 0,
#         'holds': 0,
#         'blownSaves': 0,
#         'earnedRuns': 0,
#         'whip': '-',
#         'battersFaced': 0,
#         'outs': 0,
#         'gamesPitched': 0,
#         'completeGames': 0,
#         'shutouts': 0,
#         'balls': 0,
#         'strikes': 0,
#         'strikePercentage': '-.--',
#         'hitBatsmen': 0,
#         'balks': 0,
#         'wildPitches': 0,
#         'pickoffs': 0,
#         'groundOutsToAirouts': '-.--',
#         'rbi': 0,
#         'winPercentage': '.---',
#         'pitchesPerInning': '-.--',
#         'gamesFinished': 0,
#         'strikeoutWalkRatio': '-.--',
#         'strikeoutsPer9Inn': '-.--',
#         'walksPer9Inn': '-.--',
#         'hitsPer9Inn': '-.--',
#         'runsScoredPer9': '-.--',
#         'homeRunsPer9': '-.--',
#         'inheritedRunners': 0,
#         'inheritedRunnersScored': 0,
#         'catchersInterference': 0,
#         'sacBunts': 0,
#         'sacFlies': 0,
#         'passedBall': 0,
#         'popOuts': 0,
#         'lineOuts': 0},
#        'fielding': {'gamesStarted': 1,
#         'caughtStealing': 0,
#         'stolenBases': 0,
#         'stolenBasePercentage': '.---',
#         'assists': 281,
#         'putOuts': 159,
#         'errors': 13,
#         'chances': 453,
#         'fielding': '.971',
#         'passedBall': 0,
#         'pickoffs': 0}},
#       'gameStatus': {'isCurrentBatter': False,
#        'isCurrentPitcher': False,
#        'isOnBench': False,
#        'isSubstitute': False},
#       'allPositions': [{'code': '6',
#         'name': 'Shortstop',
#         'type': 'Infielder',
#         'abbreviation': 'SS'}]},
#      'type': 'hitter',
#      'gameScore': 58,
#      'hittingGameScore': 58},
#     {'player': {'person': {'id': 571760,
#        'fullName': 'Andrew Heaney',
#        'link': '/api/v1/people/571760'},
#       'jerseyNumber': '28',
#       'position': {'code': '1',
#        'name': 'Pitcher',
#        'type': 'Pitcher',
#        'abbreviation': 'P'},
#       'status': {'code': 'A', 'description': 'Active'},
#       'parentTeamId': 119,
#       'stats': {'batting': {},
#        'pitching': {'note': '(W, 3-2)',
#         'summary': '5.0 IP, ER, 6 K, 2 BB',
#         'gamesPlayed': 1,
#         'gamesStarted': 1,
#         'flyOuts': 3,
#         'groundOuts': 3,
#         'airOuts': 7,
#         'runs': 2,
#         'doubles': 1,
#         'triples': 0,
#         'homeRuns': 1,
#         'strikeOuts': 6,
#         'baseOnBalls': 2,
#         'intentionalWalks': 0,
#         'hits': 3,
#         'hitByPitch': 0,
#         'atBats': 19,
#         'caughtStealing': 0,
#         'stolenBases': 0,
#         'stolenBasePercentage': '.---',
#         'numberOfPitches': 74,
#         'inningsPitched': '5.0',
#         'wins': 1,
#         'losses': 0,
#         'saves': 0,
#         'saveOpportunities': 0,
#         'holds': 0,
#         'blownSaves': 0,
#         'earnedRuns': 1,
#         'battersFaced': 21,
#         'outs': 15,
#         'gamesPitched': 1,
#         'completeGames': 0,
#         'shutouts': 0,
#         'pitchesThrown': 74,
#         'balls': 27,
#         'strikes': 47,
#         'strikePercentage': '.640',
#         'hitBatsmen': 0,
#         'balks': 0,
#         'wildPitches': 0,
#         'pickoffs': 0,
#         'rbi': 1,
#         'gamesFinished': 0,
#         'runsScoredPer9': '3.60',
#         'homeRunsPer9': '1.80',
#         'inheritedRunners': 0,
#         'inheritedRunnersScored': 0,
#         'catchersInterference': 0,
#         'sacBunts': 0,
#         'sacFlies': 0,
#         'passedBall': 0,
#         'popOuts': 0,
#         'lineOuts': 4},
#        'fielding': {'gamesStarted': 1,
#         'caughtStealing': 0,
#         'stolenBases': 0,
#         'stolenBasePercentage': '.---',
#         'assists': 0,
#         'putOuts': 0,
#         'errors': 0,
#         'chances': 0,
#         'fielding': '.000',
#         'passedBall': 0,
#         'pickoffs': 0}},
#       'seasonStats': {'batting': {'gamesPlayed': 0,
#         'flyOuts': 0,
#         'groundOuts': 0,
#         'airOuts': 0,
#         'runs': 0,
#         'doubles': 0,
#         'triples': 0,
#         'homeRuns': 0,
#         'strikeOuts': 0,
#         'baseOnBalls': 0,
#         'intentionalWalks': 0,
#         'hits': 0,
#         'hitByPitch': 0,
#         'avg': '.000',
#         'atBats': 0,
#         'obp': '.000',
#         'slg': '.000',
#         'ops': '.000',
#         'caughtStealing': 0,
#         'stolenBases': 0,
#         'stolenBasePercentage': '.---',
#         'groundIntoDoublePlay': 0,
#         'groundIntoTriplePlay': 0,
#         'plateAppearances': 0,
#         'totalBases': 0,
#         'rbi': 0,
#         'leftOnBase': 0,
#         'sacBunts': 0,
#         'sacFlies': 0,
#         'babip': '.---',
#         'groundOutsToAirouts': '-.--',
#         'catchersInterference': 0,
#         'pickoffs': 0,
#         'atBatsPerHomeRun': '-.--',
#         'popOuts': 0,
#         'lineOuts': 0},
#        'pitching': {'gamesPlayed': 12,
#         'gamesStarted': 12,
#         'flyOuts': 29,
#         'groundOuts': 35,
#         'airOuts': 55,
#         'runs': 27,
#         'doubles': 11,
#         'triples': 1,
#         'homeRuns': 12,
#         'strikeOuts': 84,
#         'baseOnBalls': 15,
#         'intentionalWalks': 0,
#         'hits': 46,
#         'hitByPitch': 8,
#         'atBats': 218,
#         'obp': '.285',
#         'caughtStealing': 1,
#         'stolenBases': 0,
#         'stolenBasePercentage': '.000',
#         'numberOfPitches': 948,
#         'era': '2.84',
#         'inningsPitched': '57.0',
#         'wins': 3,
#         'losses': 2,
#         'saves': 0,
#         'saveOpportunities': 0,
#         'holds': 0,
#         'blownSaves': 0,
#         'earnedRuns': 18,
#         'whip': '1.07',
#         'battersFaced': 243,
#         'outs': 171,
#         'gamesPitched': 12,
#         'completeGames': 0,
#         'shutouts': 0,
#         'pitchesThrown': 948,
#         'balls': 313,
#         'strikes': 635,
#         'strikePercentage': '.670',
#         'hitBatsmen': 8,
#         'balks': 0,
#         'wildPitches': 0,
#         'pickoffs': 0,
#         'groundOutsToAirouts': '0.64',
#         'rbi': 1,
#         'winPercentage': '.600',
#         'pitchesPerInning': '16.63',
#         'gamesFinished': 0,
#         'strikeoutWalkRatio': '5.60',
#         'strikeoutsPer9Inn': '13.26',
#         'walksPer9Inn': '2.37',
#         'hitsPer9Inn': '7.26',
#         'runsScoredPer9': '4.26',
#         'homeRunsPer9': '1.89',
#         'inheritedRunners': 0,
#         'inheritedRunnersScored': 0,
#         'catchersInterference': 0,
#         'sacBunts': 1,
#         'sacFlies': 1,
#         'passedBall': 0,
#         'popOuts': 9,
#         'lineOuts': 17},
#        'fielding': {'gamesStarted': 1,
#         'caughtStealing': 0,
#         'stolenBases': 0,
#         'stolenBasePercentage': '.---',
#         'assists': 1,
#         'putOuts': 2,
#         'errors': 1,
#         'chances': 4,
#         'fielding': '.750',
#         'passedBall': 0,
#         'pickoffs': 0}},
#       'gameStatus': {'isCurrentBatter': False,
#        'isCurrentPitcher': False,
#        'isOnBench': False,
#        'isSubstitute': False},
#       'allPositions': [{'code': '1',
#         'name': 'Pitcher',
#         'type': 'Pitcher',
#         'abbreviation': 'P'}]},
#      'type': 'starter',
#      'gameScore': 54,
#      'pitchingGameScore': 54}]},
#   'decisions': {'winner': {'id': 571760,
#     'fullName': 'Andrew Heaney',
#     'link': '/api/v1/people/571760'},
#    'loser': {'id': 605397,
#     'fullName': 'Joe Musgrove',
#     'link': '/api/v1/people/605397'}},
#   'leaders': {'hitDistance': {}, 'hitSpeed': {}, 'pitchSpeed': {}}}}

# %%
statsapi.lookup_player('jose altuve')

# https://statsapi.mlb.com/api/v1/people/514888?sportId=1&hydrate=stats(group=[batting],type=[byDateRange],startDate=09/24/2024,endDate=09/27/2024,season=2024)
# Use this query to get the player stats for T-X games for average
